# %%
# Example code to run in Jupyter or Google Colab Notebook (uncomment to try it out)
# %reload_ext tensorboard
# %tensorboard --logdir "../experiments_results/spectral resolution - two models experiments/runs_2025-02-04"
# Out:
# Reusing TensorBoard on port 6008 (pid 59878), started 0:00:30 ago. (Use '!kill 59878' to kill it.)
#       <iframe id="tensorboard-frame-f4ab0d9f3cfe851e" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-f4ab0d9f3cfe851e");
#           const url = new URL("/", window.location);
#           const port = 6008;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
